# %%
with open('./medicine_v2.txt') as f:
    medicine = f.readlines()
medicine = [name.split('\n')[0] for name in medicine]
medicine = list(set(medicine))

# %%
medicine = [name.split('\n')[0] for name in medicine]

# %%
medicine = list(set(medicine))
len(medicine)
# Out:
# 179853

# %%
import cv2
import random
import glob
import numpy as np
import matplotlib.pyplot as plt
import random
import time 
import numpy as np
import skimage
import os 

from PIL import Image,ImageDraw,ImageFont,ImageEnhance,ImageFilter
# %matplotlib inline

origin_images = glob.glob('./blank_region/*.jpg')
font = ImageFont.truetype('./font/Songti.ttc',20,index=6)
# font = ['./font/华文细黑.ttf','./font/Songti.ttc','./font/STHeitiLight.ttc']
save_dir = '/mnt/wuwenhui/git_ocr_project/chinese_ocr_densenet/train/images/dataset_len20_v1/valid/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
font_dir = ['./font/STHeitiLight.ttc','./font/Songti.ttc','./font/Hiragino Sans GB.ttc']

# %%
origin_images

# %%
font_dir = ['./font/Songti.ttc','./font/华文细黑.ttf']
# font_dir = ['./font/STHeitiLight.ttc']


def SaltAndPepper(src,percetage):  
    SP_NoiseImg=src 
    SP_NoiseNum=int(percetage*src.shape[0]*src.shape[1]) 
    for i in range(SP_NoiseNum): 
        randX=np.random.randint(0,src.shape[0]-1) 
        randY=np.random.randint(0,src.shape[1]-1) 
        if np.random.randint(0,1)==0: 
            SP_NoiseImg[randX,randY]=0 
        else: 
            SP_NoiseImg[randX,randY]=255 
    return SP_NoiseImg

def image_enhance(img):
    
    flag1 = random.random()
    if flag1 > 0.3:
        img = ImageEnhance.Contrast(img).enhance(random.random()/2+0.8)
        img = ImageEnhance.Brightness(img).enhance(random.random()/1.5+0.75)
        flag2 = random.random()
        if flag2 > 0.5:
            for _ in range(random.randint(0,4)):
                img = ImageEnhance.Sharpness(img).enhance(0.01)
#                 print('sharp one')
        elif flag2 > 0.3:
            for _ in range(random.randint(0,3)):
                img = img.filter(ImageFilter.SMOOTH_MORE)
#                 print('smooth one')
    return img



def gen_text_controlSize_with_filename(item_tuple,width=580):
    file_name,item = item_tuple
    fontName= random.choice(font_dir)
    fontSize= random.randint(18,21)
    len_item = len(item.strip())
    origin_images = glob.glob('./blank_region/*.jpg')
    if fontName == './font/Songti.ttc':
        index = 6
    else:
        index = 0
#     print(fontName,fontSize)
    font = ImageFont.truetype(font=fontName,size=fontSize,index=index)
    img = cv2.imread(random.choice(origin_images))
    image = img.copy()
    h,w = img.shape[:2]
    blank_max = max([4,int(width-1.3*(fontSize+15)*(len_item+1.5)+1)])
    blank = random.choice([4,4,4,blank_max//2,blank_max])
#     print('blank ',blank)
    text_h = random.randint(fontSize+3,fontSize+7)
    text_w = int(text_h*width/32)
    h_chop = h-text_h
    w_chop = w-text_w
#     print(h,w,text_h,text_w,blank)
    x = np.random.randint(w_chop)
    y = np.random.randint(h_chop)
    image = image[y:y+text_h,x:x+text_w]

    flag = random.random()
    if flag >0.9:
        image = skimage.util.random_noise(image,mode='gaussian',var=0.002)
        image = np.uint8(image*255)

#     print(image.shape)
    img_PIL = Image.fromarray(image[:,:,::-1])
    draw = ImageDraw.Draw(img_PIL)
    draw.text((blank,-1),item,font=font,fill=(0,0,0))
    img_PIL = image_enhance(img_PIL)
    
    img_PIL.save(save_dir+str(file_name) +'.jpg')
    return img_PIL

# %%
## 注意 keys的来源 ！！！！！
import sys
sys.path.insert(1,'/mnt/wuwenhui/git_ocr_project/chinese_ocr_densenet/densenet')

import keys_keras
characters = keys_keras.alphabet_union[1:]
len(characters)
# Out:
# 6042

# %%
def chop_to_num(text,num,characters):
    assert type(text) is str
    text = text.replace(' ','')
    while text.startswith('.'):
        text = text[1:]
    length = len(text)
#     print(length)
    if length > num :
        start = random.randint(0,length-num)
        return text[start:start+num]
    else:
        return text


def chop_to_10(text,characters):
    assert type(text) is str
    text = text.replace(' ','')
    while text.startswith('.'):
        text = text[1:]
    length = len(text)
#     print(length)
    if length > 10 :
        start = random.randint(0,length-10)
        return text[start:start+10]
    else:
        return text

# %%
num_dict = '0123456789,./%-￥'
char_dict = 'ABCDEFGHIJKLMNPQRSTUVWXYZabcdefghijklmnpqrstuvwxyz'

def gen_number_with_dot():
    serial_len = random.randint(0,5)
    num = random.random() * 10**serial_len if random.random() > 0.5 else random.randint(1,10**serial_len)
    num =  num if random.random() > 0.5 else round(random.random(),random.randint(1,2)) 
    reserve_list = [ '{:,.1f}', '{:,.2f}', '{:,.3f}']
    serial = random.choice(reserve_list).format(num)
    return serial

def gen_number_only():
    serial_len = random.randint(0,5)
    num = random.randint(1,10**serial_len)
    return '{:,}'.format(num)

def gen_serial_num(num=10):
    serial_begin = random.sample(char_dict[:]+num_dict[:10],1)
    serial = random.sample(char_dict[:]+num_dict[:],num-1)
    return ''.join(serial_begin+serial)

def gen_money_with_dollar_sign():
    serial = gen_number_with_dot()
    serial_begin = '￥'
    return serial_begin+serial 

def gen_number_with_percent_sign():
    num = random.random() if random.random() > 0.5 else round(random.random(),2)
    reserve_list = ['{:.1%}','{:.2%}','{:.3%}']
    serial = random.choice(reserve_list).format(num)
    return serial


def gen_money_with_Chinese():
    serial = gen_number_with_dot()
    Chinese_list = ["合计:" + serial, serial+"元",'总额'+serial, '单价'+serial,"合计" + serial]
    return random.choice(Chinese_list)

def up_to_10(text):
    length = len(text)
    if length < 10:
        char_text = ''.join(random.sample(char_dict,10-length))
        text = char_text+text
    return text

# %%
list_len = 500
serial_num = [gen_serial_num(20) for _ in range(list_len)]
number_only = [gen_number_only() for _ in range(list_len)]
number_with_dot = [gen_number_with_dot() for _ in range(list_len)]
money_with_dollar_sign = [gen_money_with_dollar_sign()  for _ in range(list_len)]
money_with_percent_sign = [gen_number_with_percent_sign()  for _ in range(list_len)]
random_char = [''.join(random.sample(num_dict,10)) for _ in range(list_len)]
money_with_Chinese = [gen_money_with_Chinese() for _ in range(list_len)]
total_num = number_with_dot + number_only + random_char + serial_num +\
            money_with_dollar_sign+money_with_percent_sign + money_with_Chinese + serial_num

total_num_10 = [chop_to_num(text,20,num_dict) for text in total_num]
max([len(i) for i in total_num_10])
print(len(total_num_10))
random.choice(total_num_10)
# Out:
# 4000
# '￥45,000.0'

# %%
random_char = [''.join(random.sample(characters,20)) for i in range(1000)]
random.choice(random_char)
# Out:
# '垮摄贺亥冈果陂飕剩儒荒档报♀驻讼殖熠寿俟'

# %%
medicine_10 = [item for item in medicine if len(item)> 5]
chop_10_list = [chop_to_num(item,20,characters=characters) for item in random.sample(medicine_10,20000)]
items2 = [chop_to_10(item,characters).replace(item[-1],'※') for item in random.sample(medicine,1000)]
print(len(chop_10_list))
chop_10_list = chop_10_list+items2+total_num_10+random_char
print(len(chop_10_list))
random.choice(chop_10_list)
# Out:
# 20000
# 26000
# '腺特异性抗原测定(外'

# %%
# medicine_10 = [item for item in medicine if 2<len(item) < 11]

items = [('medicine_{:08d}'.format(i),item) for i,item in enumerate(chop_10_list)]
print(max([len(item) for item in chop_10_list]))
random.choice(items)
# Out:
# 20
# ('medicine_00020842', '维生素B2片(2※')

# %%
items
# Out:
# [('medicine_00000000', '二甲双胍片(格华止)(基)0.5g*1片'),
#  ('medicine_00000001', '（克之）复方甲氧那明胶囊'),
#  ('medicine_00000002', '联苯苄唑溶液/50ml:1%/瓶'),
#  ('medicine_00000003', '激光治疗青光眼（单眼）'),
#  ('medicine_00000004', '盐酸乙哌立松片[妙纳]'),
#  ('medicine_00000005', '(乙)太子参'),
#  ('medicine_00000006', '电凝切割器（腔镜电灼器）进口'),
#  ('medicine_00000007', '石决明°1g'),
#  ('medicine_00000008', '(乙)二羟丙茶碱注射液0.25g'),
#  ('medicine_00000009', '头孢地嗪钠针（金汕秦）1.5g'),
#  ('medicine_00000010', '(乙)多巴丝肼片'),
#  ('medicine_00000011', '阿洛西林钠针*'),
#  ('medicine_00000012', '血栓通针(冻干)100mg*1瓶'),
#  ('medicine_00000013', 'j防风炒(10g*袋)'),
#  ('medicine_00000014', 'Z桑白皮1克'),
#  ('medicine_00000015', '克氏针(￠2*250)'),
#  ('medicine_00000016', '动脉导管（200元↓）体外循环/根'),
#  ('medicine_00000017', '直线型切割吻合器（国产）(胃）'),
#  ('medicine_00000018', '静注人免疫球蛋白(pH4)5%5g/10'),
#  ('medicine_00000019', '多柔比星脂质体(里葆多)针'),
#  ('medicine_00000020', '酸氨溴索口服液0.6克/100毫升*1瓶'),
#  ('medicine_00000021', '引流装置（负压引流器2000ml苏州'),
#  ('medicine_00000022', '复方甘草酸苷胶囊(基)1粒*50粒'),
#  ('medicine_00000023', '血清总蛋白测定/次'),
#  ('medicine_00000024', '双歧三联活菌胶囊(基2)0.21g*1粒'),
#  ('medicine_00000025', '柏子仁颗粒1克'),
#  ('medicine_00000026', '布比卡因注射液0.75%×5ml'),
#  ('medicine_00000027', '等级护理(一级护理)'),
#  ('medicine_00000028', '氟哌噻吨美利曲辛片/黛力新'),
#  ('medicine_00000029', '(百士欣)乌苯美司胶囊/10mg*15粒'),
#  ('medicine_00000030', '复方氨基酸注射液（18AA-V)'),
#  ('medicine_00000031', '爱得椎体成形扩张套管'),
#  ('medicine_00000032', '[合资]阿托伐他汀片20mgX7'),
#  ('medicine_00000033', '各类血细胞簇分化抗原(NK绝对值)'),
#  ('medicine_00000034', '前列地尔注射液（凯时）★'),
#  ('medicine_00000035', '曲克芦丁片（亚宝药业）'),
#  ('medicine_00000036', '/肝-胰抗原抗体(SLA/LP)测定/项'),
#  ('medicine_00000037', '纳米银创伤贴(湖南安信9*10cm)'),
#  ('medicine_00000038', '[甲]太子参★'),
#  ('medicine_00000039', '葡萄糖测定(病房)'),
#  ('medicine_00000040', '愈美甲麻敏糖浆(金叶糖浆）'),
#  ('medicine_00000041', '全蝎(颗粒)'),
#  ('medicine_00000042', '门冬氨酸鸟氨酸针2.5gX1'),
#  ('medicine_00000043', '蓝芩口服液10mlX6.0000'),
#  ('medicine_00000044', '醋酸甲地孕酮分散片(艾诺克)'),
#  ('medicine_00000045', '维生素B1片(维福佳）'),
#  ('medicine_00000046', '[哈药]头孢美唑针1g1'),
#  ('medicine_00000047', '去氧肾上腺素针[基]10mg*1支'),
#  ('medicine_00000048', '*更昔洛韦眼用凝胶（丽科明）'),
#  ('medicine_00000049', '海风藤颗粒（一方）'),
#  ('medicine_00000050', '磷酸奥司他韦胶囊（达菲）75毫克*1'),
#  ('medicine_00000051', '持续体温监测'),
#  ('medicine_00000052', '干骨折切开复位内固定术(含腓骨骨折切复内'),
#  ('medicine_00000053', '枸橼酸莫沙比利片(瑞琪）'),
#  ('medicine_00000054', '真空负压引流装置(德国美多）'),
#  ('medicine_00000055', '钆双胺注射液(欧乃影)'),
#  ('medicine_00000056', '太子参颗粒(一方)'),
#  ('medicine_00000057', '瑞舒伐他汀钙片[可定]'),
#  ('medicine_00000058', '枸杞子（颗）'),
#  ('medicine_00000059', '去甲肾上腺素针2mg:1ml'),
#  ('medicine_00000060', '栀子/1g/g'),
#  ('medicine_00000061', '注射用头孢地嗪钠B'),
#  ('medicine_00000062', '中餐_黑鱼炖汤（半条）'),
#  ('medicine_00000063', '床位费#2017.09.27'),
#  ('medicine_00000064', '胶片（14*17寸）'),
#  ('medicine_00000065', '海西丁针[头孢西丁]'),
#  ('medicine_00000066', '胚宝胶囊（康德）'),
#  ('medicine_00000067', '[善宁]奥曲肽针0.1mg*5支'),
#  ('medicine_00000068', '吻合器TLH30(自费）'),
#  ('medicine_00000069', '人工股骨柄[进口]/只'),
#  ('medicine_00000070', '强的松龙片5mg*1片'),
#  ('medicine_00000071', '彩色多普勒超声常规检查(》两个部位)*'),
#  ('medicine_00000072', '门冬氨酸鸟氨酸(瑞甘）针2.5克*1瓶'),
#  ('medicine_00000073', '替米沙坦片(美卡素)80mg*1片'),
#  ('medicine_00000074', '(基)氨茶碱注射液'),
#  ('medicine_00000075', '塞来昔布胶囊(西乐葆）/200mg*6s'),
#  ('medicine_00000076', '一次性胃管（苏州）'),
#  ('medicine_00000077', '心输出量测定'),
#  ('medicine_00000078', '机采血小板(SDP)1U/1'),
#  ('medicine_00000079', '人凝血酶原复合物200IU*1瓶'),
#  ('medicine_00000080', '胸腹水常规检查（心包积液）'),
#  ('medicine_00000081', '钠测定（血气）'),
#  ('medicine_00000082', '皮肤质地改善激光治疗'),
#  ('medicine_00000083', '[是]颈椎前路固定螺钉（进口）'),
#  ('medicine_00000084', '乙型肝炎表面抗原测定（定量）/项'),
#  ('medicine_00000085', '利培酮片（单克）'),
#  ('medicine_00000086', '毒血凝酶注射液(速乐涓)1毫升/1单位*'),
#  ('medicine_00000087', '小金胶囊（基）'),
#  ('medicine_00000088', '康)酪酸梭菌二联活菌散500mg*20袋'),
#  ('medicine_00000089', '异丙托溴铵(爱全乐)雾化溶液'),
#  ('medicine_00000090', '正清风痛宁缓释片（医）'),
#  ('medicine_00000091', '(免)(乙)苏肽生粉针30ug'),
#  ('medicine_00000092', '可吸收缝线UL877/根'),
#  ('medicine_00000093', '三七粉/3g/袋'),
#  ('medicine_00000094', '尿激酶针10万单位*1支'),
#  ('medicine_00000095', '(基)茶碱缓释片'),
#  ('medicine_00000096', '（特价）尿感宁颗粒'),
#  ('medicine_00000097', '抗肝细胞抗体测定'),
#  ('medicine_00000098', '血清维生素测定（贫血/每种维生素）'),
#  ('medicine_00000099', '[基]双歧杆菌三联活菌胶囊0.21g*3'),
#  ('medicine_00000100', '心肌酶谱常规检查'),
#  ('medicine_00000101', '基】(0.5g)拉氧头孢钠针0.5g*1'),
#  ('medicine_00000102', '复方莪术油栓(康妇特栓)(基)'),
#  ('medicine_00000103', '$山香圆叶1g'),
#  ('medicine_00000104', '康复新液(好医生)'),
#  ('medicine_00000105', '使用超声切割止血刀加收（颅脑）/人次'),
#  ('medicine_00000106', '净病房床位费（洁净级别达到100级及以上'),
#  ('medicine_00000107', '替普瑞酮(施维舒)胶囊'),
#  ('medicine_00000108', '导丝(443Cougar-亲水涂层）'),
#  ('medicine_00000109', '鼻内镜检查(次)'),
#  ('medicine_00000110', '方利巴韦林口服溶液(平康)10ml*10'),
#  ('medicine_00000111', '维生素A棕榈酯眼用凝胶'),
#  ('medicine_00000112', '丙酸氟替卡松鼻喷雾剂/辅舒良/特价'),
#  ('medicine_00000113', '等级护理#2018.05.17'),
#  ('medicine_00000114', 'j野菊花(10g*袋)1克'),
#  ('medicine_00000115', '博自攻型规则螺纹锥型锁定钉I型2.4/3'),
#  ('medicine_00000116', '多种微量元素－2针(安达美)10毫升*1'),
#  ('medicine_00000117', '复方胆通胶囊.银诺克'),
#  ('medicine_00000118', '盐酸左氧氟沙星胶囊(左克)4520221'),
#  ('medicine_00000119', '槲寄生（医）'),
#  ('medicine_00000120', '5葡萄糖氯化钠针(双管软袋)基'),
#  ('medicine_00000121', '复方甘草酸苷针[美能]./20ml/支'),
#  ('medicine_00000122', '妇科千金胶囊（基）'),
#  ('medicine_00000123', '福辛普利片[常]10mg*14片'),
#  ('medicine_00000124', '黄毛耳草（医）'),
#  ('medicine_00000125', '*5%葡萄糖注射液(双管软袋)(济民)'),
#  ('medicine_00000126', '(特价)复明片（医）'),
#  ('medicine_00000127', '血浆(ml)'),
#  ('medicine_00000128', '(甲)盐酸克林霉素棕榈酸酯分散片'),
#  ('medicine_00000129', '钩藤（浙鼎堂）'),
#  ('medicine_00000130', '氯化钠针0.9%:10mlX1'),
#  ('medicine_00000131', '阿卡波糖胶囊（基药）'),
#  ('medicine_00000132', '三九胃泰颗粒（无糖）'),
#  ('medicine_00000133', '嵌顿性宫内节育器取出术/次'),
#  ('medicine_00000134', '氯化钠注射液/10.0ml/支'),
#  ('medicine_00000135', '不带装置〓噻托溴铵粉雾剂18ug*10粒'),
#  ('medicine_00000136', '夏枯草(K)'),
#  ('medicine_00000137', '气管套管金属(内芯统配)国产'),
#  ('medicine_00000138', '复方益肝灵胶囊'),
#  ('medicine_00000139', '孟鲁司特钠片（成人自费）'),
#  ('medicine_00000140', '素肠溶胶囊[美红][0.25克(25万单'),
#  ('medicine_00000141', '种植生物激光烤瓷冠'),
#  ('medicine_00000142', '止痒湿疹合剂（自制）500ml'),
#  ('medicine_00000143', '中餐_大蒜平菇香干肉片'),
#  ('medicine_00000144', '丙泊酚针（力蒙欣）100毫克/10毫升*'),
#  ('medicine_00000145', '2014.05.28等级护理'),
#  ('medicine_00000146', '妇科千金胶囊/0.4g*24/盒'),
#  ('medicine_00000147', 'j石膏(10g)1克'),
#  ('medicine_00000148', '硝苯地平控释片(7)'),
#  ('medicine_00000149', '血游离脂肪酸测定(血游离有机酸)'),
#  ('medicine_00000150', '[国产]奥曲肽针0.3mg1'),
#  ('medicine_00000151', '*氨酚咖黄烷胺片'),
#  ('medicine_00000152', '注射用美罗培南(倍能)/0.5g/支'),
#  ('medicine_00000153', '布林佐胺噻吗洛尔滴眼液(!派立噻)'),
#  ('medicine_00000154', '环胞霉素Ａ(山地明)注射液'),
#  ('medicine_00000155', '帕罗西汀片(乐友)[基]'),
#  ('medicine_00000156', '纱布块[6cm*8cm]'),
#  ('medicine_00000157', '奥氮平口崩片[再普乐]▲5mg*7片'),
#  ('medicine_00000158', '复方氨基酸注射液'),
#  ('medicine_00000159', '光学相干生物测量IOLMaster'),
#  ('medicine_00000160', 'ZF[瑞白]重组人粒细胞集100ugX1'),
#  ('medicine_00000161', '续有创性血压监测【31070200200'),
#  ('medicine_00000162', '蒲公英/g/g'),
#  ('medicine_00000163', '吸收止血绫(泰绫5*8cm)(北京泰科)'),
#  ('medicine_00000164', '(特价)硫酸氢氯吡格雷片（泰嘉）（医）'),
#  ('medicine_00000165', '硫酸沙丁胺醇吸入气雾剂（信可宁）'),
#  ('medicine_00000166', '美罗培南针/0.5g/支'),
#  ('medicine_00000167', '半枝莲(净)'),
#  ('medicine_00000168', 'K北沙参/1g/g'),
#  ('medicine_00000169', '9%氯化钠注射液/250ml2.25g/'),
#  ('medicine_00000170', '一次性延长管'),
#  ('medicine_00000171', '叶片(天保宁)/19.2mg*24#/盒'),
#  ('medicine_00000172', '灵芝1.2)小无柄'),
#  ('medicine_00000173', 'K醋香附(颗粒)'),
#  ('medicine_00000174', '欧乃派克（350、100ml)'),
#  ('medicine_00000175', '抗缪勒氏管激素（AMH)'),
#  ('medicine_00000176', '石膏棉纸15cm*10s'),
#  ('medicine_00000177', '医用弹性绷带（平纹）'),
#  ('medicine_00000178', '电凝切割器（FCS9）五次摊销'),
#  ('medicine_00000179', '辅酶A针100u*1'),
#  ('medicine_00000180', '[基]维生素C注射液'),
#  ('medicine_00000181', '银翘颗粒（片）'),
#  ('medicine_00000182', '*珍珠明目滴眼液'),
#  ('medicine_00000183', '中餐_笋尖排骨'),
#  ('medicine_00000184', '心脏起搏器(进口）'),
#  ('medicine_00000185', '(甲)盐酸利多卡因注射液0.4g'),
#  ('medicine_00000186', '海珠喘息定片.厦门84片'),
#  ('medicine_00000187', 'k大黄*1克'),
#  ('medicine_00000188', '养血荣筋丸（北京同仁堂）'),
#  ('medicine_00000189', '盐酸头孢他美酯干混悬剂'),
#  ('medicine_00000190', '(恒康)复方聚乙二醇电解质散A'),
#  ('medicine_00000191', '◆多西环素肠溶胶囊'),
#  ('medicine_00000192', '幽门螺旋杆菌抗体测定'),
#  ('medicine_00000193', '泪囊鼻腔引流支架'),
#  ('medicine_00000194', '盐酸氨基葡萄糖胶囊（维尔固）'),
#  ('medicine_00000195', 'j合欢皮(10g*袋)'),
#  ('medicine_00000196', '米曲菌胰酶片（慷彼申）20片'),
#  ('medicine_00000197', '肉桂（饮片）'),
#  ('medicine_00000198', '院前急救费（危重急救病人）'),
#  ('medicine_00000199', '去乙酰毛花苷注射液/0.4mg/2ml*'),
#  ('medicine_00000200', '林格氏液500ml*1袋'),
#  ('medicine_00000201', '蒙脱石散剂/限'),
#  ('medicine_00000202', '(基)垂体后叶素针6u*10支'),
#  ('medicine_00000203', '强力天麻杜仲胶囊（通化）'),
#  ('medicine_00000204', '白术（颗粒）1G'),
#  ('medicine_00000205', '坦洛新缓释胶囊'),
#  ('medicine_00000206', '(0.5)左氧氟沙星片'),
#  ('medicine_00000207', '沐舒坦口服液[氨溴索]'),
#  ('medicine_00000208', '鼻前庭囊肿切除术'),
#  ('medicine_00000209', '复方消化酶胶囊（达吉）CO*20'),
#  ('medicine_00000210', '盐酸二甲双胍肠溶胶囊(君力达）'),
#  ('medicine_00000211', '(C)呋塞米注射液20mg/2mlX10'),
#  ('medicine_00000212', '等级护理#2018.05.27'),
#  ('medicine_00000213', '棉签(一次性)'),
#  ('medicine_00000214', '一次性敷贴(10*9)'),
#  ('medicine_00000215', '清肺合剂(自制）500ml*1瓶'),
#  ('medicine_00000216', '血游离有机酸测定（2十四酰基肉'),
#  ('medicine_00000217', '碳酸氢钠注射液0.5克/10毫升*1支'),
#  ('medicine_00000218', '克林霉素针(莱美特宁)☆'),
#  ('medicine_00000219', '重楼/1g/g'),
#  ('medicine_00000220', '氨溴索针(沐舒坦)(基)15mg*1支'),
#  ('medicine_00000221', '胞磷胆碱钠胶囊（思考林胶囊）0.1g*4'),
#  ('medicine_00000222', '[合资]瑞舒伐他汀片10mgX7'),
#  ('medicine_00000223', '深静脉导管（合资、双腔）'),
#  ('medicine_00000224', '复济外用溶液/63000au*15ml/'),
#  ('medicine_00000225', '复方感冒灵颗粒(宝瑞坦)'),
#  ('medicine_00000226', '术后引流/次(1.000)'),
#  ('medicine_00000227', '养胃颗粒5g*12袋'),
#  ('medicine_00000228', '＆款冬花1g'),
#  ('medicine_00000229', 'j干姜5克*1克'),
#  ('medicine_00000230', '藿香正气丸（仲景宛西）'),
#  ('medicine_00000231', '[巨和粒]白介素11针1.5mg1'),
#  ('medicine_00000232', '威高亚华YH0113型圆棒'),
#  ('medicine_00000233', '阿成贝切(Achenbach)儿童行为量'),
#  ('medicine_00000234', '异丙肾上腺素针[基]▼1mg*2支'),
#  ('medicine_00000235', '(是)甲状腺球蛋白测定'),
#  ('medicine_00000236', '咳特灵胶囊（元和）'),
#  ('medicine_00000237', '利血生片（利可君片）'),
#  ('medicine_00000238', '孕酮测定(P)'),
#  ('medicine_00000239', '替普瑞酮胶囊(施维舒)/50mg*20#'),
#  ('medicine_00000240', '(是)食入物变应原筛查(限)'),
#  ('medicine_00000241', '(甲)一般细菌涂片检查'),
#  ('medicine_00000242', '吻合器（030418)'),
#  ('medicine_00000243', '气压治疗(肢体气压治疗)（≥3部'),
#  ('medicine_00000244', '甲强龙〓甲泼尼龙针40mg'),
#  ('medicine_00000245', '10%葡萄糖水针,100毫升/袋'),
#  ('medicine_00000246', '精密输液器（KT)静脉输液不含输液器/支'),
#  ('medicine_00000247', '卤米松软膏（澳能）*'),
#  ('medicine_00000248', '(甲)甘露醇针'),
#  ('medicine_00000249', '[出]盐酸地尔硫卓片'),
#  ('medicine_00000250', '＆血滞通胶囊'),
#  ('medicine_00000251', '医用抗血栓压力带（长筒）/双(100.0'),
#  ('medicine_00000252', '复合物胶囊(力蜚能)/0.15g*1粒/'),
#  ('medicine_00000253', '曲安奈德益康唑软膏20g*1支'),
#  ('medicine_00000254', '*◆他克莫司胶囊0.5mgX50.000'),
#  ('medicine_00000255', '内障囊外摘除联合青光眼人工晶体植入术/次'),
#  ('medicine_00000256', '◆复方甲氧那明胶囊1粒X60'),
#  ('medicine_00000257', '静脉输液(ICU专用)'),
#  ('medicine_00000258', '丹参(草药)1g*1g'),
#  ('medicine_00000259', 'B型钠尿肽定量测定（BNP）(急诊)'),
#  ('medicine_00000260', '电动起立床训练/次(100.00%)'),
#  ('medicine_00000261', '脂质体注射液(里保多)20mg/10ml'),
#  ('medicine_00000262', '氨氯地平阿托伐他汀片*1片'),
#  ('medicine_00000263', '复方甘草酸铵注射液（康体多）'),
#  ('medicine_00000264', '凝血功能常规检查/次'),
#  ('medicine_00000265', '凝血酶原复合物200IU*1瓶'),
#  ('medicine_00000266', '冬瓜子*1G'),
#  ('medicine_00000267', '(普米克令舒)布地奈德'),
#  ('medicine_00000268', '盐酸哌替啶注射液0.1g/2ml'),
#  ('medicine_00000269', '盐酸氨溴索颗粒'),
#  ('medicine_00000270', '桑寄生/饮片/g'),
#  ('medicine_00000271', '[是]双腔吸氧管(鼻氧管)'),
#  ('medicine_00000272', '甲氯化钠注射液'),
#  ('medicine_00000273', '(颗粒)醋青皮'),
#  ('medicine_00000274', '消化道软组织夹2（胃镜室）'),
#  ('medicine_00000275', '普通针刺(磁针)(≤20个穴位)。'),
#  ('medicine_00000276', '阿法骨化醇软胶囊0.25微克*1粒'),
#  ('medicine_00000277', '左旋氨氯地平片(施慧达)[基]'),
#  ('medicine_00000278', '各种白介素测定(IL-6)/种'),
#  ('medicine_00000279', '敷贴(35X40)'),
#  ('medicine_00000280', '吻合器-钉仓(SR55)(自费)'),
#  ('medicine_00000281', '络活喜片(苯磺酸氨氯地平)(国基)'),
#  ('medicine_00000282', 'j甘草炒(5g*袋)1克'),
#  ('medicine_00000283', '18氟－脱氧葡萄糖断层显像（肿瘤一个部位'),
#  ('medicine_00000284', '复方氨基酸针(18AA-5)'),
#  ('medicine_00000285', '糠酸莫米松乳膏(艾洛松)(基)'),
#  ('medicine_00000286', '中心静脉导管组ARROW/ES-0470'),
#  ('medicine_00000287', '丁螺环酮片(奇比特)/5mg*40#/片'),
#  ('medicine_00000288', '一次性气切套管进口万灵科'),
#  ('medicine_00000289', '氟比洛芬酯注射液(凯纷)/5ml:50m'),
#  ('medicine_00000290', '(40mg)复方甘草酸苷注射液'),
#  ('medicine_00000291', '颈椎间盘臭氧消融术'),
#  ('medicine_00000292', '角膜厚度检查'),
#  ('medicine_00000293', '@强力枇杷露250ml'),
#  ('medicine_00000294', '甲苯酸（止血芳酸）针100毫克/10毫升'),
#  ('medicine_00000295', '口腔内固定材料（进口）'),
#  ('medicine_00000296', '奥沙西泮片/15mg/片'),
#  ('medicine_00000297', '麻醉中彩超引导'),
#  ('medicine_00000298', '甲胎蛋白测定（其它）'),
#  ('medicine_00000299', '鲑降钙素注射液（固通宁）'),
#  ('medicine_00000300', '!米力农针（鲁南力康）5毫克/5毫升*1'),
#  ('medicine_00000301', '糠酸莫米松(摩弥齐)乳膏'),
#  ('medicine_00000302', '医用透明质酸钠凝胶(防粘连材料)国产'),
#  ('medicine_00000303', '双歧三联活菌肠溶胶囊（贝飞达）'),
#  ('medicine_00000304', '青光眼引流阀'),
#  ('medicine_00000305', '小儿豉翘清热颗粒（济川6d）'),
#  ('medicine_00000306', '*5mg孟鲁司特钠咀嚼片(顺尔宁）'),
#  ('medicine_00000307', '一次性静脉留置针(Y型)/只'),
#  ('medicine_00000308', '更换引流袋/次(100.00%)'),
#  ('medicine_00000309', '数字化摄影（CR）-单侧手正·斜位。'),
#  ('medicine_00000310', '左克2ml（盐酸左氧氟'),
#  ('medicine_00000311', '抗着丝点抗体/次'),
#  ('medicine_00000312', '连花清瘟颗粒6克*10袋'),
#  ('medicine_00000313', '硫酸镁针25%:10ml1'),
#  ('medicine_00000314', '维生素B2片[基]5mg*100片'),
#  ('medicine_00000315', '灭活冰冻血浆100ML/次'),
#  ('medicine_00000316', '糖类抗原测定(CA-153)'),
#  ('medicine_00000317', 'L盐酸二甲双胍片'),
#  ('medicine_00000318', '阿昔洛韦针250mgX1'),
#  ('medicine_00000319', '二次剖宫产术(2胎及以上)/次'),
#  ('medicine_00000320', '一次性注射器（20ml）侧孔'),
#  ('medicine_00000321', '多烯磷脂酰胆碱(易善复胶囊)'),
#  ('medicine_00000322', '高分子脱离敏剂(牙脱'),
#  ('medicine_00000323', '白眉蛇毒血凝酶针（邦亭）2iu*1瓶'),
#  ('medicine_00000324', '头孢呋辛酯胶囊（国药0.125*12s）'),
#  ('medicine_00000325', '安奈德注射液(国产)40mg/1ml*1'),
#  ('medicine_00000326', '可吸收止血材料（止血装置、巴德'),
#  ('medicine_00000327', '钛夹（LT200）'),
#  ('medicine_00000328', '#*（冲洗用）氯化钠注射液(500ml)'),
#  ('medicine_00000329', '冻干重组人脑利钠肽针'),
#  ('medicine_00000330', '杭白菊（小包装）'),
#  ('medicine_00000331', '黄芪颗粒（好好）'),
#  ('medicine_00000332', '血细胞染色体检查'),
#  ('medicine_00000333', '(乙)双歧三联活菌胶囊(贝飞达)限'),
#  ('medicine_00000334', '氨氯地平阿托伐他汀钙片7片'),
#  ('medicine_00000335', '奥曲肽针0.1毫克*1支'),
#  ('medicine_00000336', '硬膜外连续镇痛'),
#  ('medicine_00000337', '非那雄胺片（薄膜衣片）'),
#  ('medicine_00000338', '(特价)阿托伐他汀钙片(立普妥)（医）'),
#  ('medicine_00000339', 'ml氯化钠注射液（软袋）250ml*1袋'),
#  ('medicine_00000340', '血清药物浓度测定(地高辛）/种'),
#  ('medicine_00000341', '混合痔嵌顿手法松解'),
#  ('medicine_00000342', '负压引流装置PVA-3（威高）15*10'),
#  ('medicine_00000343', '清开灵颗粒(无糖型）1.5克*36袋'),
#  ('medicine_00000344', '（金康）汉防己甲素片20mg*12片'),
#  ('medicine_00000345', '氢氯吡格雷片（泰嘉）25毫克*1片'),
#  ('medicine_00000346', '尿感宁颗粒(2016大)'),
#  ('medicine_00000347', '诊察费#2017.06.20'),
#  ('medicine_00000348', '硫酸羟氯喹片（纷乐）'),
#  ('medicine_00000349', '(免)(甲)黄连素片0.1g'),
#  ('medicine_00000350', '帕利哌酮缓释片(芮达)3mg*7片'),
#  ('medicine_00000351', '(0.3g)加巴喷丁胶囊'),
#  ('medicine_00000352', '复托义齿修复(塑料小支架)'),
#  ('medicine_00000353', '硫酸阿托品片/0.3mg/片'),
#  ('medicine_00000354', '维生素C针(基)0.5g*1'),
#  ('medicine_00000355', '浙贝母/1g/g'),
#  ('medicine_00000356', '阿米卡星针[低]0.2g/2ml*10支'),
#  ('medicine_00000357', '抗环瓜氨酸肽抗体(CCP'),
#  ('medicine_00000358', '巨细胞病毒抗体'),
#  ('medicine_00000359', '导丝（COOKTSMG）'),
#  ('medicine_00000360', '艾司奥美拉唑针/40mg/支'),
#  ('medicine_00000361', '敷贴（优韧宁）53*70'),
#  ('medicine_00000362', '碘佛醇注射液'),
#  ('medicine_00000363', '一次性胃管(胃肠减压进口)'),
#  ('medicine_00000364', '儿）氨溴索(沐舒坦)口服液600毫克/1'),
#  ('medicine_00000365', '当归10克*1包'),
#  ('medicine_00000366', '(颗粒)葛根'),
#  ('medicine_00000367', '低频脉冲电治疗》=3部位/人次/人次'),
#  ('medicine_00000368', '胶体果胶铋胶囊AA（医）'),
#  ('medicine_00000369', '粘敷贴(透明)6*7(1624W)'),
#  ('medicine_00000370', '哌拉西林钠他唑巴坦钠针1.125克*1瓶'),
#  ('medicine_00000371', 'MR片费(14*17)'),
#  ('medicine_00000372', '多烯磷脂酰胆碱注射液232.5mg*5m'),
#  ('medicine_00000373', '注射用头孢曲松钠1g*1瓶'),
#  ('medicine_00000374', '乌鸡白凤丸（亿通）&（医）'),
#  ('medicine_00000375', '(基)注射用头孢呋辛钠'),
#  ('medicine_00000376', '复方多维元素片(玛特纳)CO*30片'),
#  ('medicine_00000377', '（特价）复方氨酚烷胺胶囊(快克)'),
#  ('medicine_00000378', '谱四项（CK、AST、LDH、CK-MB'),
#  ('medicine_00000379', '阿奇霉素干混悬剂（海南普利）'),
#  ('medicine_00000380', '◆复方克霉唑乳膏(II)20gX1.00'),
#  ('medicine_00000381', '外耳道良性肿物切除术'),
#  ('medicine_00000382', '盐酸多西环素胶囊'),
#  ('medicine_00000383', '天一止咳糖浆1mlX120.0000'),
#  ('medicine_00000384', '盐酸洛哌丁胺胶囊2mgX6'),
#  ('medicine_00000385', '[是]肝素帽(进口)'),
#  ('medicine_00000386', '注射用甲氨喋呤/0.1/瓶'),
#  ('medicine_00000387', '缬沙坦分散片(平欣)(基)40mg*24'),
#  ('medicine_00000388', '牛黄解毒片（葵花）'),
#  ('medicine_00000389', '强生特殊缝线(EPM8206)进口'),
#  ('medicine_00000390', '卡式Rh血型鉴定加收'),
#  ('medicine_00000391', '福莫特罗粉60吸;160/4.5ugX1'),
#  ('medicine_00000392', '枳实颗粒(一方)'),
#  ('medicine_00000393', '短波体腔治疗(≥3部位）'),
#  ('medicine_00000394', '六神丸（小水丸）'),
#  ('medicine_00000395', '黄体酮针(基)20mg*10支'),
#  ('medicine_00000396', '(乙)莫沙比利胶囊△'),
#  ('medicine_00000397', '苯扎氯铵贴.100片'),
#  ('medicine_00000398', '(太宁)复方角菜酸酯栓'),
#  ('medicine_00000399', '硫酸异帕米星注射液,（基）△'),
#  ('medicine_00000400', '复方消化酶胶囊(基)'),
#  ('medicine_00000401', '天丹通络胶囊0.4克*60粒'),
#  ('medicine_00000402', '静脉采血(/)'),
#  ('medicine_00000403', '布洛芬缓释胶囊(仁和）'),
#  ('medicine_00000404', '注射用头孢呋辛钠(安可欣)(1.5g)'),
#  ('medicine_00000405', '利巴韦林分散片100毫克*1片'),
#  ('medicine_00000406', '黄体酮胶囊(益玛欣)(基）/50mg*2'),
#  ('medicine_00000407', '一次性活检钳（奥林巴斯FD-410LR）'),
#  ('medicine_00000408', '木糖醇粉/250g/袋'),
#  ('medicine_00000409', 'X线计算机体层(CT)平扫一部螺旋/次'),
#  ('medicine_00000410', '烯酸人工晶状体(Aqua-Sense)('),
#  ('medicine_00000411', '硫酸羟氯喹片(赛能)'),
#  ('medicine_00000412', '导尿管（三腔、江西）'),
#  ('medicine_00000413', '利可君片（利血生）[基]'),
#  ('medicine_00000414', '甲巯咪唑膜衣片(赛治)'),
#  ('medicine_00000415', 'CD19检测'),
#  ('medicine_00000416', '20一次性注射器20ml*'),
#  ('medicine_00000417', '枸地氯雷他定片/8.8mg*6/片'),
#  ('medicine_00000418', '大扶康针[氟康唑]'),
#  ('medicine_00000419', '股骨颈骨折闭合复位内固定术'),
#  ('medicine_00000420', '▲重酒石酸间羟胺注射液/10mg/支'),
#  ('medicine_00000421', '阿司匹林肠溶片(奥吉娜)'),
#  ('medicine_00000422', '柴胡/颗粒剂/克'),
#  ('medicine_00000423', '参松养心胶囊/0.4g*36粒/盒'),
#  ('medicine_00000424', '氧氟沙星眼膏(迪可罗)/3.5g/支'),
#  ('medicine_00000425', '抗核抗体系列测定.'),
#  ('medicine_00000426', '北柴胡配方颗粒'),
#  ('medicine_00000427', '（乙）依托考昔片'),
#  ('medicine_00000428', '口服补液盐Ⅲ5.125g*6包'),
#  ('medicine_00000429', '德福莫特罗粉吸入剂(基)(小)160ug'),
#  ('medicine_00000430', '射针（内镜用注射针）（进口）(FLEX)'),
#  ('medicine_00000431', '一次注射手柄'),
#  ('medicine_00000432', '一次性双腔导尿管Bardic马来西亚'),
#  ('medicine_00000433', '真空采血管/支'),
#  ('medicine_00000434', '点刀费（三四类手术）副高'),
#  ('medicine_00000435', '支持导管（进口）①'),
#  ('medicine_00000436', '洁肤净洗剂200毫升*1瓶'),
#  ('medicine_00000437', '血清泌乳素测定（生殖中心）'),
#  ('medicine_00000438', '(甲△)阿司匹林肠溶片'),
#  ('medicine_00000439', '乳果糖口服溶液'),
#  ('medicine_00000440', 'J肝素帽.贝朗.进口'),
#  ('medicine_00000441', '呋塞米片（速尿）[低]20mg*100片'),
#  ('medicine_00000442', '(新）球结膜放射状切开冲洗+减压术'),
#  ('medicine_00000443', '?′????'),
#  ('medicine_00000444', '磺胺醋酰钠滴眼液（思芬）'),
#  ('medicine_00000445', '复方鲜竹沥液(江西南昌）'),
#  ('medicine_00000446', '（4:1）萄糖氯化钠注'),
#  ('medicine_00000447', '制乳香/1g/g'),
#  ('medicine_00000448', '惠多发式切割缝合钉匣60-3.8L(进)'),
#  ('medicine_00000449', '医用胶原蛋白海绵（可即邦）/片'),
#  ('medicine_00000450', '氢氯噻嗪片/25mg*100/片'),
#  ('medicine_00000451', '瑞舒伐他汀胶囊（鲁南）'),
#  ('medicine_00000452', '痔疮胶囊（吉林天泰）'),
#  ('medicine_00000453', '长春西汀（润坦）针10毫克/2毫升*1支'),
#  ('medicine_00000454', '(基)碳酸钙D3片（钙尔奇D）★△'),
#  ('medicine_00000455', '血清游离三碘甲状原氨酸FT3测定(外)'),
#  ('medicine_00000456', '钩藤/1g/g'),
#  ('medicine_00000457', '镫骨活动度检测(盖来试验)'),
#  ('medicine_00000458', '糜蛋白酶针4000单位*1支'),
#  ('medicine_00000459', '气压治疗(肢体气压治疗)≥3部位'),
#  ('medicine_00000460', '电针(包括普通电针、电热针灸、电冷针)'),
#  ('medicine_00000461', '红细胞沉降率测定(ESR)(血粘度)/次'),
#  ('medicine_00000462', '王不留行颗粒'),
#  ('medicine_00000463', '空心接骨螺钉'),
#  ('medicine_00000464', '丙戊酸钠缓释片(德巴金)'),
#  ('medicine_00000465', '斑马导丝（MTN-BM-89/45-A）'),
#  ('medicine_00000466', '板蓝根颗粒/10g*20袋/盒'),
#  ('medicine_00000467', '红霉素软膏1%10g*1支'),
#  ('medicine_00000468', '特比萘芬片(奥邦)'),
#  ('medicine_00000469', '伙食费中餐花菜肉丝，洋葱土豆'),
#  ('medicine_00000470', '(特价)急支糖浆'),
#  ('medicine_00000471', '一般细菌培养(咽拭子)'),
#  ('medicine_00000472', '金银花（盛海堂）'),
#  ('medicine_00000473', '生山楂颗粒剂'),
#  ('medicine_00000474', '伙食费中餐筒骨豆腐汤'),
#  ('medicine_00000475', '可折叠一件工人工晶状体(非球面)'),
#  ('medicine_00000476', '安脑片0.5克*24片'),
#  ('medicine_00000477', '乙)注射用复方甘草酸苷（限）40mg*1'),
#  ('medicine_00000478', '射液(塑料安瓿)/10ml:1.0g/支'),
#  ('medicine_00000479', '阿托伐他汀钙片[立普妥]/20mg*7片'),
#  ('medicine_00000480', '果糖二磷酸钠注射液10克/100毫升*1'),
#  ('medicine_00000481', '植入性材料钉仓（HJQZ60）'),
#  ('medicine_00000482', '特需门诊服务费513243'),
#  ('medicine_00000483', '颅骨钛板（421527）'),
#  ('medicine_00000484', '替米沙坦片[低](诺金平)20mg*30'),
#  ('medicine_00000485', '静脉输液(门诊/含注射器)'),
#  ('medicine_00000486', '[甲]雌二醇测定'),
#  ('medicine_00000487', '敷贴（优韧宁）90*100'),
#  ('medicine_00000488', '醇雾化溶液(万托林)5mg/1ml*1m'),
#  ('medicine_00000489', '步长消乳散结胶囊（医）'),
#  ('medicine_00000490', '胰岛素注射器/个(100.00%)'),
#  ('medicine_00000491', '头孢克洛缓释片(Ⅱ)[希刻劳]'),
#  ('medicine_00000492', '透明敷料（IV300010*12）'),
#  ('medicine_00000493', '苯扎氯铵贴(创口贴)'),
#  ('medicine_00000494', '氨基酸注射液（18AA-II)21.25'),
#  ('medicine_00000495', '血型抗体效价测定（IgG抗AB）'),
#  ('medicine_00000496', '造影导管(TEMPO4-5F)进口介入科'),
#  ('medicine_00000497', '＆(限）壳脂胶囊'),
#  ('medicine_00000498', '钙维生素D3片（钙尔奇D)600毫克*3'),
#  ('medicine_00000499', '牙齿美容修复术（复杂）'),
#  ('medicine_00000500', '地特胰岛素注射液'),
#  ('medicine_00000501', '多囊肾去顶减压术（单侧）'),
#  ('medicine_00000502', '麻醉中彩超引导(YB)'),
#  ('medicine_00000503', '一次性小针刀4号'),
#  ('medicine_00000504', '膦甲酸钠氯化钠注射液(可耐)3克/250'),
#  ('medicine_00000505', '传感器(进口，BLS)'),
#  ('medicine_00000506', '盐酸小檗碱片(南京白敬宇)'),
#  ('medicine_00000507', '肝素帽（外院）'),
#  ('medicine_00000508', '医用骨折夹板（肱骨外科颈）'),
#  ('medicine_00000509', '哌卡因/肾上腺素注射液CO1.8毫升*1'),
#  ('medicine_00000510', '安乃近针[基]'),
#  ('medicine_00000511', '埃索美拉唑片[耐信]'),
#  ('medicine_00000512', '注射用盐酸瑞芬太尼1mg1mgX1'),
#  ('medicine_00000513', '复方嗜酸乳杆菌片★'),
#  ('medicine_00000514', '酸枣仁(炒)'),
#  ('medicine_00000515', '针(甘乐力250ml:12.5g:2.2'),
#  ('medicine_00000516', '深静脉导管（国产）ICU'),
#  ('medicine_00000517', '经胃肠镜电切治疗/次'),
#  ('medicine_00000518', '鳞状细胞癌相关抗原测定（SCC）鄣吴'),
#  ('medicine_00000519', '@硝苯地平缓释片(伲福达)20毫克*1片'),
#  ('medicine_00000520', '奥卡西平片（0.15*50s意大利）'),
#  ('medicine_00000521', '阿奇霉素胶囊(葵花)'),
#  ('medicine_00000522', '营养输注管路(玉升200元↓)ICU.C'),
#  ('medicine_00000523', '苦碟子注射液20ml*1支'),
#  ('medicine_00000524', '藿香正气水（一力罗定制药）'),
#  ('medicine_00000525', '冰片（草药）'),
#  ('medicine_00000526', '复方对乙酰氨基酚片（Ⅱ）'),
#  ('medicine_00000527', '安奇片[阿莫西林克拉维]'),
#  ('medicine_00000528', '重感灵片(嘉应）'),
#  ('medicine_00000529', '*苯巴比妥钠注射液'),
#  ('medicine_00000530', '双氯芬酸钠缓释胶囊（I）/步长3'),
#  ('medicine_00000531', '克痢沙胶囊(基）'),
#  ('medicine_00000532', '阿米替林片[低]'),
#  ('medicine_00000533', '酚磺乙胺（止血敏）注射剂'),
#  ('medicine_00000534', '深静脉穿刺导管(PICC)I/套'),
#  ('medicine_00000535', '可吸收线（3/0）/包'),
#  ('medicine_00000536', '**美司钠注射液（美安）'),
#  ('medicine_00000537', '曲唑酮片50mgX20.0000'),
#  ('medicine_00000538', '可吸收螺钉(国产）'),
#  ('medicine_00000539', '制大黄/熟大黄'),
#  ('medicine_00000540', '钠测定-血-急诊'),
#  ('medicine_00000541', '术后引流（胸腔闭式引流管一根）/次'),
#  ('medicine_00000542', '钠钾葡萄糖针'),
#  ('medicine_00000543', '标准桃金娘油胶囊'),
#  ('medicine_00000544', '(乙)羧甲司坦口服液(无糖型)临'),
#  ('medicine_00000545', '羊膜腔注药中期引产术'),
#  ('medicine_00000546', '(特价）拉米夫定片(贺普丁片)（医）'),
#  ('medicine_00000547', '●(甲)来立信片剂0.2g'),
#  ('medicine_00000548', '奥美拉唑肠溶胶囊20mg*1'),
#  ('medicine_00000549', '注射用门冬氨酸钾镁'),
#  ('medicine_00000550', '碳酸氢钠(苏打粉)500g*1袋'),
#  ('medicine_00000551', '(跌)盐酸贝那普利片10mgX10.00'),
#  ('medicine_00000552', '(甲)制玉竹'),
#  ('medicine_00000553', '深静脉导管（德国）ICU'),
#  ('medicine_00000554', '产科含胎儿、宫腔、每增加一个胎儿加收20'),
#  ('medicine_00000555', '入用异丙托溴铵溶液/2ml:250ug/'),
#  ('medicine_00000556', '*5%葡萄糖注射液(单管软袋济民)'),
#  ('medicine_00000557', '酒地龙*1克'),
#  ('medicine_00000558', '络活喜(苯磺酸氨氯地平片）'),
#  ('medicine_00000559', '三拗片0.5克*24片'),
#  ('medicine_00000560', '格列齐特缓释片（达美康缓释片）'),
#  ('medicine_00000561', '雷贝拉唑钠肠溶胶囊(济诺)@（医）'),
#  ('medicine_00000562', '头孢克洛分散片0.25g*12片'),
#  ('medicine_00000563', '赤芍（颗粒剂）'),
#  ('medicine_00000564', '◆氨氯地平片（压氏达）'),
#  ('medicine_00000565', '隐血试验(OB)/项'),
#  ('medicine_00000566', '磷酸钠盐口服溶液(善时）'),
#  ('medicine_00000567', '救护车费(起步价）'),
#  ('medicine_00000568', '胞磷胆碱针(基)'),
#  ('medicine_00000569', '可吸收缝线vcp371H(美国)'),
#  ('medicine_00000570', 'j杜仲炒(15g*袋)'),
#  ('medicine_00000571', '大活络丸（雷允上）'),
#  ('medicine_00000572', '利福平胶囊0.15g1'),
#  ('medicine_00000573', '紫苏子*1G'),
#  ('medicine_00000574', '蜈蚣15cm'),
#  ('medicine_00000575', '复方氟米松软膏(奥深)15g*1支'),
#  ('medicine_00000576', '霉素/地塞米松滴眼液(典必殊)5ml*1'),
#  ('medicine_00000577', '复方氨基酸胶囊30片'),
#  ('medicine_00000578', 'SANT-(14-22)-20-PLV库'),
#  ('medicine_00000579', '半夏糖浆（简装）'),
#  ('medicine_00000580', '(缓释)美托洛尔缓释片'),
#  ('medicine_00000581', '复方醋酸地塞米松（皮炎平）霜'),
#  ('medicine_00000582', '次手术:充填式无张力疝修补术'),
#  ('medicine_00000583', '依帕司他片50毫克*12片'),
#  ('medicine_00000584', '旋复花/1/g'),
#  ('medicine_00000585', '盐酸左西替利嗪胶囊(畅然)△'),
#  ('medicine_00000586', '静注人免疫球蛋白(pH4)/2.5g/瓶'),
#  ('medicine_00000587', '氨茶碱针[低]'),
#  ('medicine_00000588', ',（一次性自毁式,1ml，,2ml，,5'),
#  ('medicine_00000589', '(佐朋)哌拉西林钠他唑巴坦钠针'),
#  ('medicine_00000590', '抗炎合剂（妇科抗炎Ⅰ号浓煎剂）168ml'),
#  ('medicine_00000591', '血栓通针/100mg/支'),
#  ('medicine_00000592', '一次性注射器(5ML)1'),
#  ('medicine_00000593', '复方丹参片（白药）'),
#  ('medicine_00000594', '依帕司他片(伊衡)50mg*1片'),
#  ('medicine_00000595', '龙齿(先煎)'),
#  ('medicine_00000596', '碳酸钙D3片（钙尔奇D600）'),
#  ('medicine_00000597', '55（集中）（捷迈进口）陶瓷股骨头和衬垫'),
#  ('medicine_00000598', '益智仁（炒益智仁）'),
#  ('medicine_00000599', '透析器U2000（血液滤过器）'),
#  ('medicine_00000600', '丁克阴道泡腾片)盐酸特比萘芬阴道泡腾片'),
#  ('medicine_00000601', '巴曲亭)注射用矛头蝮蛇血凝酶2unit*'),
#  ('medicine_00000602', '射用头孢呋辛钠(明可欣)0.75克*1瓶'),
#  ('medicine_00000603', '甲泼尼龙片(美卓乐）4mg*1片'),
#  ('medicine_00000604', '（络活喜）氨氯地平片(基）'),
#  ('medicine_00000605', '10%氯化钠针(浓）10%10毫升*5支'),
#  ('medicine_00000606', 'j阿胶珠(10g*袋)'),
#  ('medicine_00000607', '经胃肠镜电凝治疗/次'),
#  ('medicine_00000608', '槲寄生颗粒1克'),
#  ('medicine_00000609', '(乙)氯吡格雷片'),
#  ('medicine_00000610', '医用激光胶片（8*10、杭州健培'),
#  ('medicine_00000611', '素A棕榈酸酯眼用凝胶/5g:5000iu'),
#  ('medicine_00000612', '苁蓉通便口服液10ml×6支'),
#  ('medicine_00000613', '格列齐特缓释片.仙孚迪'),
#  ('medicine_00000614', '双氯芬酸二乙胺乳膏（'),
#  ('medicine_00000615', '盐酸特比萘芬乳膏0.15g/15g*1支'),
#  ('medicine_00000616', '亚安培南/西司他丁钠盐'),
#  ('medicine_00000617', '低频脉冲电治疗（≥3部位）2'),
#  ('medicine_00000618', '脑电视频监测(24小时)'),
#  ('medicine_00000619', '便通片（医）'),
#  ('medicine_00000620', '抗精子抗体混合凝集试验(精液)（生殖中心'),
#  ('medicine_00000621', '枫蓼肠胃康分散片(海南黄隆）'),
#  ('medicine_00000622', '黄斑马导丝(进)/次'),
#  ('medicine_00000623', '[出]普瑞巴林胶囊'),
#  ('medicine_00000624', '空调费#2018.02.22'),
#  ('medicine_00000625', '利肺片(星宝）'),
#  ('medicine_00000626', '(乙)氨甲苯酸针(0.1g)'),
#  ('medicine_00000627', '快速血浆反应素试验（RPR4）'),
#  ('medicine_00000628', '脱发颗粒剂协定方'),
#  ('medicine_00000629', '阿胶（福牌）#'),
#  ('medicine_00000630', 'j玄明粉3克*1克'),
#  ('medicine_00000631', '三金片(桂林三金）'),
#  ('medicine_00000632', '炒陈皮（6g、10g）'),
#  ('medicine_00000633', '一次性无菌注射器（10ML龙德）'),
#  ('medicine_00000634', '威灵仙10g'),
#  ('medicine_00000635', '甲氨喋呤针0.1g'),
#  ('medicine_00000636', '缬沙坦氢氯噻嗪片(复代文)CO80mg*'),
#  ('medicine_00000637', '恩必普（丁苯酞软胶囊）'),
#  ('medicine_00000638', '尿激酶针/10.0万u/瓶'),
#  ('medicine_00000639', '抗病毒丸口服液'),
#  ('medicine_00000640', '（特价）尼莫地平片(医)'),
#  ('medicine_00000641', '甲硝唑维B片'),
#  ('medicine_00000642', '（特价）鼻炎康片甲'),
#  ('medicine_00000643', '医用膜(薄膜巾)'),
#  ('medicine_00000644', '甲太子参/饮片/g'),
#  ('medicine_00000645', '(乙)胸腺肽al粉针1.6mg<基泰>★'),
#  ('medicine_00000646', '注射液（玻璃瓶）0.9%500ml*1瓶'),
#  ('medicine_00000647', '人工膝关节(国产）'),
#  ('medicine_00000648', '谷精草颗粒剂'),
#  ('medicine_00000649', '上清片（太极）（医）AA'),
#  ('medicine_00000650', '复方北豆根氨酚那敏片（吉林省天泰）'),
#  ('medicine_00000651', '清热散结片（佰消安）'),
#  ('medicine_00000652', '肌腱吻合术。'),
#  ('medicine_00000653', '[是]心脏彩色多普勒超声(自费10%）'),
#  ('medicine_00000654', '术中B超检查(一个部位)/次'),
#  ('medicine_00000655', '新鲜冰冻血浆(100ml)'),
#  ('medicine_00000656', '普济痔疮栓1.3g/1粒*10粒'),
#  ('medicine_00000657', '根端囊肿摘除术/每牙'),
#  ('medicine_00000658', '◎注射用头孢哌酮钠舒巴坦钠1g*1瓶'),
#  ('medicine_00000659', '感冒清胶囊（南昌）'),
#  ('medicine_00000660', '甲地孕酮分散片(宜利治)'),
#  ('medicine_00000661', '头孢呋辛酯片*(伏乐新'),
#  ('medicine_00000662', '动脉导管闭合术'),
#  ('medicine_00000663', '右美托咪定针200ug:2mlX1'),
#  ('medicine_00000664', '(基)（保列治）非那雄胺片5毫克*10片'),
#  ('medicine_00000665', '(x)丹参配方颗粒10克*1袋'),
#  ('medicine_00000666', '辛伐他汀分散片(基）'),
#  ('medicine_00000667', '罗帕酮片(悦复隆)/150mg*10#/'),
#  ('medicine_00000668', '塞来昔布胶囊[西乐葆](0.2g*6粒)'),
#  ('medicine_00000669', '丹参多酚酸盐针/100mg/瓶'),
#  ('medicine_00000670', '巴金片)丙戊酸钠缓释片500mg*30片'),
#  ('medicine_00000671', '[乙]◆吸入用异丙托溴胺溶液'),
#  ('medicine_00000672', '粘贴伤口敷料10*30'),
#  ('medicine_00000673', 'ABO红细胞定型（献血员）'),
#  ('medicine_00000674', '消炎利胆片(广东嘉应)'),
#  ('medicine_00000675', '甲胎蛋白测定（AFP）'),
#  ('medicine_00000676', '标准桃金娘油肠溶胶囊[常]'),
#  ('medicine_00000677', '注用人免疫球蛋白(pH4)/2.5g:5'),
#  ('medicine_00000678', '决明子（虚）'),
#  ('medicine_00000679', '替米沙坦胶囊（欣益尔）（医）'),
#  ('medicine_00000680', '亮丙瑞林缓释微球针'),
#  ('medicine_00000681', '(得理多）卡马西平片'),
#  ('medicine_00000682', '氯化钠注射液10ml:90mgX1'),
#  ('medicine_00000683', '恩替卡韦分散片（润众）0.5毫克*7片'),
#  ('medicine_00000684', '小檗胺片(四川中方）'),
#  ('medicine_00000685', '利奈唑胺葡萄糖注射液100ml<申请>③'),
#  ('medicine_00000686', '化三醇胶丸(罗盖全)0.25μg*10粒'),
#  ('medicine_00000687', '双氯芬酸胶囊(英太青)'),
#  ('medicine_00000688', '敷贴（3L）国产9*20'),
#  ('medicine_00000689', '维血宁口服液/25ml*6支/盒'),
#  ('medicine_00000690', '一次性包皮环切缝合器（狼和）'),
#  ('medicine_00000691', '肠道病毒71型测定'),
#  ('medicine_00000692', '1/4855-01/5874-01（进）'),
#  ('medicine_00000693', '麻仁丸[低]60克'),
#  ('medicine_00000694', '桑菊感冒颗粒（本草纲目）'),
#  ('medicine_00000695', '葡萄糖注射液'),
#  ('medicine_00000696', '活血止痛片.今越36片'),
#  ('medicine_00000697', '部位多头带包扎术/每部位(100.00%'),
#  ('medicine_00000698', '胰岛素注射液/10ml:400单位/支'),
#  ('medicine_00000699', 'j川贝母(最细粉)1克*1袋'),
#  ('medicine_00000700', '盐酸氟桂利嗪胶囊[西比灵]■5mg*1粒'),
#  ('medicine_00000701', '三磷酸腺苷二钠（ATP）片'),
#  ('medicine_00000702', '（特价）步长前列舒通胶囊（医保）'),
#  ('medicine_00000703', '(保列冶)非那雄胺片5mg*1'),
#  ('medicine_00000704', '明可欣/头孢呋辛'),
#  ('medicine_00000705', '汉防己甲素片/20mg*6s/片'),
#  ('medicine_00000706', '甘精胰岛素注射液(来得时)'),
#  ('medicine_00000707', '敷贴(换药9*25)/张'),
#  ('medicine_00000708', '清热解毒口服液（四川好医生）'),
#  ('medicine_00000709', '碳酸钙(迪巧)'),
#  ('medicine_00000710', '西曲瑞克针0.25mg'),
#  ('medicine_00000711', '[成人]孟鲁司特钠咀嚼片[常]'),
#  ('medicine_00000712', '晚餐_菠菜肉丝'),
#  ('medicine_00000713', '头皮包块（浅表器官彩超）'),
#  ('medicine_00000714', '真空试管[蓝色3630952.7ml]'),
#  ('medicine_00000715', '羟甲唑啉喷雾剂[低]5mg/10ml*1'),
#  ('medicine_00000716', '[甲]川芎★'),
#  ('medicine_00000717', '（希福尼）头孢地尼分'),
#  ('medicine_00000718', '粉(200/0.5)氯化钠针(基)500'),
#  ('medicine_00000719', '血红蛋白测定(HbICU)'),
#  ('medicine_00000720', '林可霉素B6乳膏'),
#  ('medicine_00000721', '塑料瓶)0.9%氯化钠注射液0.9%10'),
#  ('medicine_00000722', '诺和锐30(门冬胰岛素30注射液)'),
#  ('medicine_00000723', '!枸橼酸舒芬太尼注射液/50ug*1ml'),
#  ('medicine_00000724', '司特钠咀嚼片(顺尔宁)(基)4mg*5片'),
#  ('medicine_00000725', '盐酸伐昔洛韦分散片（丽科分）'),
#  ('medicine_00000726', '方氯化钠注射液(非P软袋)/500ml/'),
#  ('medicine_00000727', '来膦酸针(密固达)/100ml:5mg/'),
#  ('medicine_00000728', '穴位贴敷治疗。'),
#  ('medicine_00000729', '黄连上清片(仁和)'),
#  ('medicine_00000730', '特需挂号费[4]'),
#  ('medicine_00000731', '颈椎牵引器（普通）'),
#  ('medicine_00000732', '日常生活能力评定(自费)'),
#  ('medicine_00000733', '米力农针5mg1'),
#  ('medicine_00000734', '红细胞不规则抗体测定(＞8种)加收（自费'),
#  ('medicine_00000735', '彩色多普勒超声常规检查（腹部）'),
#  ('medicine_00000736', '脯(优泌乐25)/3ml:300iu/支'),
#  ('medicine_00000737', '胰岛素针/10ml:400iu/瓶'),
#  ('medicine_00000738', '●(甲)拜阿司匹灵片0.1g'),
#  ('medicine_00000739', '盐酸胺碘酮片/0.2g/片'),
#  ('medicine_00000740', '可吸收止血材料（明胶海绵)'),
#  ('medicine_00000741', '甲地孕酮片(宜利治)160mg*30片'),
#  ('medicine_00000742', '钆喷酸葡胺注射液（20ML、广州）'),
#  ('medicine_00000743', '血清总胆红素测定。(套餐)'),
#  ('medicine_00000744', '采血器(真空管阳普红黄紫蓝绿）'),
#  ('medicine_00000745', '其他材料费(晓墅)'),
#  ('medicine_00000746', '动静脉置管护理（限1次/日）'),
#  ('medicine_00000747', '乙]鲑鱼降钙素喷鼻剂(限)[金尔力喷鼻2'),
#  ('medicine_00000748', 'j合欢花*1克'),
#  ('medicine_00000749', '沙利度胺片25毫克*1'),
#  ('medicine_00000750', '*注射用生长抑素/3mg/瓶'),
#  ('medicine_00000751', '(乙)艾迪注射液(限)'),
#  ('medicine_00000752', '电解质测定（西亩）'),
#  ('medicine_00000753', '静脉采血器（BD回弹式）'),
#  ('medicine_00000754', '气囊导尿管（贝朗）'),
#  ('medicine_00000755', '维生素B6注射液/0.1/支'),
#  ('medicine_00000756', '拇囊炎手术治疗（单侧）次手术(70%)'),
#  ('medicine_00000757', '克氏针(钛合金)(1.5*250)'),
#  ('medicine_00000758', '乳腺肿物切除术/单'),
#  ('medicine_00000759', '吸痰管（1）'),
#  ('medicine_00000760', '伙食费(心理科)'),
#  ('medicine_00000761', '高山红景天口服液'),
#  ('medicine_00000762', '酚注射液（静安）/20ml：0.2g/支'),
#  ('medicine_00000763', '气囊导尿管(三腔水凝胶)进口'),
#  ('medicine_00000764', '高压氧舱专用遥测监护'),
#  ('medicine_00000765', '辅酶Q10片[能气朗]'),
#  ('medicine_00000766', '甲状腺部分切除术（单侧）次手术(半价)'),
#  ('medicine_00000767', '兰索拉唑肠溶胶囊&（医）'),
#  ('medicine_00000768', '专家门诊(副高)加收诊查费'),
#  ('medicine_00000769', 'L-谷酰胺呱仑酸钠'),
#  ('medicine_00000770', '替米沙坦片40mg*28片'),
#  ('medicine_00000771', '格列齐特缓释片30毫克*1片'),
#  ('medicine_00000772', '神经阻滞麻醉(星状）。'),
#  ('medicine_00000773', '恩替卡韦分散片'),
#  ('medicine_00000774', '静脉留置针（BD）'),
#  ('medicine_00000775', '葡萄糖测定(指测）'),
#  ('medicine_00000776', '卡替洛尔滴眼液（美开朗）'),
#  ('medicine_00000777', '柯惠缝线（VP557X）'),
#  ('medicine_00000778', '车前草K1克'),
#  ('medicine_00000779', '石膏药棉纸(6寸)'),
#  ('medicine_00000780', '双氯芬酸二乙胺乳膏(J乙)20g*1支'),
#  ('medicine_00000781', '导丝（219/669）'),
#  ('medicine_00000782', '运动疗法[器械训练]/次'),
#  ('medicine_00000783', '硫酸氢氯吡格雷片'),
#  ('medicine_00000784', '牛黄蛇胆川贝液（孔府制药）'),
#  ('medicine_00000785', 'CT胶片(进口)(DRYSTAR'),
#  ('medicine_00000786', '透明敷贴(自费）'),
#  ('medicine_00000787', '胆石利通片0.45g1'),
#  ('medicine_00000788', '可吸收止血纱（强生1961）2.5*5.'),
#  ('medicine_00000789', '尔片[低](德国Salutas)5mg*'),
#  ('medicine_00000790', '巴戟天(颗粒)'),
#  ('medicine_00000791', '(特价）排石颗粒(医)'),
#  ('medicine_00000792', '特殊缝线进口EH7625'),
#  ('medicine_00000793', '一次性包皮环切缝合器（江西）'),
#  ('medicine_00000794', '山海螺（羊乳）'),
#  ('medicine_00000795', '(多达一)氨氯地平阿托伐他汀钙片7片'),
#  ('medicine_00000796', '(60ml)布洛芬混悬液'),
#  ('medicine_00000797', '蒸南五味子1g'),
#  ('medicine_00000798', '阿托伐他汀钙片B'),
#  ('medicine_00000799', 'O/4、W8557、8557PG、普理灵'),
#  ('medicine_00000800', 'k党参（生）10克'),
#  ('medicine_00000801', '磷霉素氨丁三醇散3克*1盒'),
#  ('medicine_00000802', '二十五味珊瑚丸(水丸)1g*10粒'),
#  ('medicine_00000803', '盐酸雷尼替丁注射液50毫克*10支'),
#  ('medicine_00000804', '丙泊酚针/0.1g:10ml/支'),
#  ('medicine_00000805', '▲盐酸吗啡注射液/1ml:10mg/支'),
#  ('medicine_00000806', '旋切导管（EV3）'),
#  ('medicine_00000807', '感器（DRAEGERMP00994/3M'),
#  ('medicine_00000808', '8×10干试片(ACFA干式片DT2B)'),
#  ('medicine_00000809', '天麻壮骨丸A/天麻壮骨丸'),
#  ('medicine_00000810', '阿桔片1片X1.0000'),
#  ('medicine_00000811', '一次性使用吸痰包/个(100.000%)'),
#  ('medicine_00000812', '*盐酸特拉唑嗪片（高特灵）/2mg/片'),
#  ('medicine_00000813', '合欢皮/1:20/g'),
#  ('medicine_00000814', '血液滤过器（费森F*800）'),
#  ('medicine_00000815', '吡柔比星针（依比路）'),
#  ('medicine_00000816', '普通针刺(体针)(＞20个穴位)'),
#  ('medicine_00000817', '盐酸米多君片(米维)2.5mg*1片'),
#  ('medicine_00000818', '天麻素注射液[天眩清]2毫升*6支(分装'),
#  ('medicine_00000819', '坦度螺酮片（希德）10毫克*42片'),
#  ('medicine_00000820', '10%葡萄糖注射液[非PVC膜]500m'),
#  ('medicine_00000821', '尼莫地平片30mgX20.0000'),
#  ('medicine_00000822', '阿托伐他汀钙胶囊(河南)(基)'),
#  ('medicine_00000823', '莪术(免煎)'),
#  ('medicine_00000824', '林钠(冻干)/2.0g(200万IU)/'),
#  ('medicine_00000825', '咽鼓管再造术'),
#  ('medicine_00000826', '牙周微创超声深刮术'),
#  ('medicine_00000827', '万古霉素针(稳可信)0.5g*1瓶'),
#  ('medicine_00000828', '透骨草(K)'),
#  ('medicine_00000829', '(丽珠得乐)枸橼酸铋钾颗粒110mg*5'),
#  ('medicine_00000830', '恶性软组织肉瘤广泛切除'),
#  ('medicine_00000831', '二甲双胍（国光）'),
#  ('medicine_00000832', '(免)(乙)罗哌卡因注射液100mg<申'),
#  ('medicine_00000833', '氢氯吡格雷片（波立维）'),
#  ('medicine_00000834', '吲哚美辛栓（消炎痛）'),
#  ('medicine_00000835', '②头孢克肟胶囊/世福素'),
#  ('medicine_00000836', '(乙)注射用盐酸溴己新粉针'),
#  ('medicine_00000837', '闭合器（LF4318/1537）'),
#  ('medicine_00000838', '乳酸脱氢酶测定(LDH)'),
#  ('medicine_00000839', '[出]阿托伐他汀钙胶囊(尤佳)(基)'),
#  ('medicine_00000840', '腹部彩超常规检查'),
#  ('medicine_00000841', 'J[甲]地塞米松片[/]0.75mg*1'),
#  ('medicine_00000842', '甲钴胺片(弥可保)500ug*1片'),
#  ('medicine_00000843', '22直型头皮留置针'),
#  ('medicine_00000844', '??á?·?'),
#  ('medicine_00000845', '清开灵颗粒(无糖)'),
#  ('medicine_00000846', '碳酸氢钠注射液/250ml:12.5/瓶'),
#  ('medicine_00000847', '复方碳酸氢钠含漱液（制）'),
#  ('medicine_00000848', '(甲)胰岛素注射液(正规)'),
#  ('medicine_00000849', '盐益智（虚）'),
#  ('medicine_00000850', '一次性延长管（心内科）PM148/12'),
#  ('medicine_00000851', '◆碘佛醇针(安射力)'),
#  ('medicine_00000852', '输液用肝素帽(常规圣光)'),
#  ('medicine_00000853', '(丙)<哈尔滨>奥拉西坦注射液1g'),
#  ('medicine_00000854', '替米沙坦片.上海现代'),
#  ('medicine_00000855', '叶酸片[低]5mg*100粒'),
#  ('medicine_00000856', '鼻氧管(单鼻苏州1.8m)国产'),
#  ('medicine_00000857', '软癥散结合剂(自制）'),
#  ('medicine_00000858', '[丙]气管插管固定器'),
#  ('medicine_00000859', '雷贝拉唑钠肠溶片(波利特)[常]'),
#  ('medicine_00000860', '尿液爱迪氏计数(Addis)'),
#  ('medicine_00000861', '茺蔚子(小胡麻）'),
#  ('medicine_00000862', '医学验光/人'),
#  ('medicine_00000863', '长春西汀针[常]10mg*1支'),
#  ('medicine_00000864', '合欢皮（医）'),
#  ('medicine_00000865', '硫辛酸注射液/6ml:0.15g/支'),
#  ('medicine_00000866', '[警]盐酸利多卡因针'),
#  ('medicine_00000867', '复方消化酶胶囊(星昊美彤)20粒'),
#  ('medicine_00000868', 'K首乌藤15克'),
#  ('medicine_00000869', '五味子（醋）'),
#  ('medicine_00000870', '活检穿刺针(德国宝雅)进口乳房B超'),
#  ('medicine_00000871', '氯雷他定片(OTC)'),
#  ('medicine_00000872', '复方氯化钠注射液[软]500ml*1瓶'),
#  ('medicine_00000873', '@华法林钠片(糖衣)'),
#  ('medicine_00000874', '螺旋CT平扫（≥三部位）'),
#  ('medicine_00000875', '抗血栓梯度压力带（长筒）国产'),
#  ('medicine_00000876', '枸橼酸莫沙比利片(大)'),
#  ('medicine_00000877', '针筒(1ml)'),
#  ('medicine_00000878', '一次性穿刺针(20g)'),
#  ('medicine_00000879', '多吉美)甲苯磺酸索拉非尼片0.2g*60'),
#  ('medicine_00000880', '磷酸肌酸钠针1gX1'),
#  ('medicine_00000881', '复方青黛胶囊/0.5g*48/粒'),
#  ('medicine_00000882', '厄贝沙坦片(吉佳)'),
#  ('medicine_00000883', '培养细胞染色体检查'),
#  ('medicine_00000884', '阿糖胞苷针(赛德萨)/0.1g/瓶'),
#  ('medicine_00000885', '植入性材料补片(10*10)（国产）'),
#  ('medicine_00000886', '(1mg)他克莫司(华东)胶囊'),
#  ('medicine_00000887', '钆贝葡胺注射液'),
#  ('medicine_00000888', '!(10ml)盐酸利多卡因针'),
#  ('medicine_00000889', '复方利血平片（杭州民生）'),
#  ('medicine_00000890', '蛤蚧定喘胶囊'),
#  ('medicine_00000891', '盐酸特比萘芬乳膏(999优诺平)'),
#  ('medicine_00000892', '红豆蔻（饮片）'),
#  ('medicine_00000893', '土贝母（颗）'),
#  ('medicine_00000894', '孟鲁司特钠咀嚼片（顺尔宁5mg)'),
#  ('medicine_00000895', '复方倍他米松针'),
#  ('medicine_00000896', 'BD留置针383405'),
#  ('medicine_00000897', '赖氨酸硫酸锌口服溶液(促长灵)'),
#  ('medicine_00000898', '普伐他汀片（美百乐镇）40毫克*1'),
#  ('medicine_00000899', '尔血)重组人粒细胞刺激因子针150ug/'),
#  ('medicine_00000900', '○(甲)开博通片12.5mg'),
#  ('medicine_00000901', '$焦栀子1g'),
#  ('medicine_00000902', '复方曲安奈德乳膏/15g/支'),
#  ('medicine_00000903', '0.2健择〓吉西他滨针▼0.2g*1支'),
#  ('medicine_00000904', '乙型肝炎核心抗体测定(Anti-HBc)'),
#  ('medicine_00000905', '尿感宁颗粒(无蔗型)'),
#  ('medicine_00000906', '特殊变应原(多价变应原)筛查(皮)*'),
#  ('medicine_00000907', '调节/集合测定'),
#  ('medicine_00000908', '直线型切割吻合器钉仓ECR45(进)/个'),
#  ('medicine_00000909', '一次性无菌引流连接装置(艾贝尔)'),
#  ('medicine_00000910', 'X光胶片(11*11)'),
#  ('medicine_00000911', '危B]碘化油针(法国)4.8克/10毫升'),
#  ('medicine_00000912', '★头孢呋辛酯胶囊'),
#  ('medicine_00000913', '克(5/0-7/0)(手外伤皮瓣术)(Y'),
#  ('medicine_00000914', '奥硝唑氯化钠针(塑瓶)0.5g/100m'),
#  ('medicine_00000915', '3人房(传染病区及外科'),
#  ('medicine_00000916', '马应龙麝香痔疮膏(10g)'),
#  ('medicine_00000917', 'KSS盐酸左氧氟沙星胶囊(逸舒甘)'),
#  ('medicine_00000918', '透明质酸钠0.8ML/支'),
#  ('medicine_00000919', '吸入用乙酰半胱氨酸溶液(富露施)0.3g'),
#  ('medicine_00000920', '马应龙痔疮膏（马应龙）'),
#  ('medicine_00000921', '盐酸昂丹司琼注射液8mg:4mlX1'),
#  ('medicine_00000922', '双黄连口服液(浓缩型)10ml*1'),
#  ('medicine_00000923', '安全留置针（383732飞码）'),
#  ('medicine_00000924', '康)双歧杆菌三联活菌胶囊0.21g*36'),
#  ('medicine_00000925', 'j银花(5g*袋)*1克'),
#  ('medicine_00000926', '西吡氯铵含漱液200毫升*1瓶'),
#  ('medicine_00000927', '洛芬滴眼液(普南扑灵)/5mg/5ml/'),
#  ('medicine_00000928', '常规心电图检查*'),
#  ('medicine_00000929', '@☆阿托品针'),
#  ('medicine_00000930', '紫外线治疗(短波)/照射'),
#  ('medicine_00000931', '[甲]β2微球蛋白测定'),
#  ('medicine_00000932', '七氟烷10ml'),
#  ('medicine_00000933', '钉匣(美外）内镜用(ENDOGIA)60'),
#  ('medicine_00000934', '大豆黄卷（医）'),
#  ('medicine_00000935', '胚宝胶囊（医）'),
#  ('medicine_00000936', '次手术:肺大泡切除修补术'),
#  ('medicine_00000937', '麝香镇痛膏[基]8cm/12cm*10贴'),
#  ('medicine_00000938', '生脉注射液(10ml)'),
#  ('medicine_00000939', '蜜紫菀J/1g/g'),
#  ('medicine_00000940', '吸痰管（可调负压吸引管）'),
#  ('medicine_00000941', '（特价）福辛普利钠片(蒙诺)（医）'),
#  ('medicine_00000942', '胃康胶囊&（医）'),
#  ('medicine_00000943', '□羟苯磺酸钙片0.5克*20片'),
#  ('medicine_00000944', '(甲)利多卡因注射液(2%l]'),
#  ('medicine_00000945', '窝沟封闭术（耐磨材料）'),
#  ('medicine_00000946', 'j葛根炒10克*1克'),
#  ('medicine_00000947', '玫瑰花/DJ'),
#  ('medicine_00000948', 'eng)疾病特异型肠内营养200ml*1'),
#  ('medicine_00000949', '生大黄(大黄)/3g/袋'),
#  ('medicine_00000950', '一次性穿刺针(器)(12mm*10mm)'),
#  ('medicine_00000951', '雷尼替丁针50毫克*1支'),
#  ('medicine_00000952', '庆大霉素普罗卡因（胃炎胶囊）胶囊*1粒'),
#  ('medicine_00000953', '绵萆薢（净）'),
#  ('medicine_00000954', '普通床位费(50)'),
#  ('medicine_00000955', '金匮肾气丸(胡庆余堂）'),
#  ('medicine_00000956', '雷公藤多苷片(得恩德）'),
#  ('medicine_00000957', '一次性使用精密过滤输液器(国产)'),
#  ('medicine_00000958', '☆安儿宁颗粒'),
#  ('medicine_00000959', '鲜益母草胶囊0.4g*24粒'),
#  ('medicine_00000960', '2013.06.28床位费'),
#  ('medicine_00000961', '金雀根（医）'),
#  ('medicine_00000962', '[甲]一次性引流袋'),
#  ('medicine_00000963', '0.9%氯化钠注射液250'),
#  ('medicine_00000964', '血沉用真空采血管'),
#  ('medicine_00000965', '单硝酸异山梨酯片(欣康)[低]20mg*'),
#  ('medicine_00000966', '罗替卡松吸入剂（舒利迭）500ug*1盒'),
#  ('medicine_00000967', '颌骨病灶刮除术'),
#  ('medicine_00000968', 'k(凯尼汀)克霉唑阴道片'),
#  ('medicine_00000969', '☆生脉胶囊(基)'),
#  ('medicine_00000970', 'k醋青皮*1克'),
#  ('medicine_00000971', '*炒鸡内金（颗粒）'),
#  ('medicine_00000972', '中餐_萝卜丝炒肉丝'),
#  ('medicine_00000973', '黄芪(K)1克'),
#  ('medicine_00000974', '奥美拉唑肠溶胶囊.大金奥康'),
#  ('medicine_00000975', '兰索拉唑针[常]'),
#  ('medicine_00000976', '真空采血试管(分离胶)'),
#  ('medicine_00000977', '一次性注射器(20ml专项护理)'),
#  ('medicine_00000978', '吸收缝线(抗菌薇乔VCP9215H)进口'),
#  ('medicine_00000979', '克拉霉素缓释片（诺邦）0.5g*7片'),
#  ('medicine_00000980', '血清蛋白电泳'),
#  ('medicine_00000981', '马应龙麝香痔疮膏(基)20g*1支'),
#  ('medicine_00000982', '双氯芬酸纳肠溶缓释胶囊(诺福丁）'),
#  ('medicine_00000983', '▲注射用盐酸表柔比星/10mg/瓶'),
#  ('medicine_00000984', '黄柏/1/g'),
#  ('medicine_00000985', '辛缓释胶囊(哈乐)/0.2mg*10粒/'),
#  ('medicine_00000986', '0mg羟考酮缓释片(奥施康定)40mg*'),
#  ('medicine_00000987', '灭菌透气薄膜（施乐辉）4008（10*1'),
#  ('medicine_00000988', '复方氢溴酸右美沙芬糖浆（右美舒坦）'),
#  ('medicine_00000989', '空肠弯曲菌培养及鉴定（C)'),
#  ('medicine_00000990', '来氟米特片10mgX16'),
#  ('medicine_00000991', '金果饮（口服液）15ml*10支'),
#  ('medicine_00000992', '专用创面覆盖材料（维斯第B型）17.8*'),
#  ('medicine_00000993', '糖类抗原测定(CA72－4)'),
#  ('medicine_00000994', '尼莫地平片[尼膜同]/30mg(20)/'),
#  ('medicine_00000995', '神经阻滞麻醉(宫旁)/次'),
#  ('medicine_00000996', '(特价)左归丸（医）'),
#  ('medicine_00000997', '六味地黄胶囊（佰消安）'),
#  ('medicine_00000998', '经内镜逆行胰胆管造影(ERCP)'),
#  ('medicine_00000999', '抗AMA-M2抗体测定'),
#  ...]

# %%
from multiprocessing import Pool,cpu_count
pool = Pool(cpu_count()//4)

items = [('medicine_{:08d}'.format(i),item) for i,item in enumerate(chop_10_list)]
# random.shuffle(items)

start = time.time()
# %time result = pool.map(gen_text_controlSize_with_filename,items)
end = time.time()
print(end-start,cpu_count()//4)

# %%
import json

dict_label = {file_name+'.jpg':item.replace(' ','') for file_name,item in items}

# 保存成.json
with open(save_dir+"valid_label.json",'w',encoding='utf-8') as json_file:   
        json.dump(dict_label,json_file)
        
# load json 文件
with open(save_dir+"valid_label.json",'r',encoding='utf-8') as json_file:
    txt=json.load(json_file)

# %%
len(txt)

# %%
txt_list = [(key,value) for key,value in txt.items()]
print(txt_list[:10],len(txt_list),len(items))
'凯纷)氟比洛芬酯注射' in chop_10_list

# %%
# import keys_keras
item = random.choice(items)
# %time result = gen_text_controlSize_with_filename(item)
# k = random.randint(0,5)

# result = image_enhance(result)
#  result = ImageEnhance.Contrast(result).enhance(0.5)

# result = ImageEnhance.Brightness(result).enhance(1.5)

# for i in range(k):
#     result = result.filter(ImageFilter.SMOOTH_MORE)
# img_list = glob.glob('/mnt/wuwenhui/git_ocr_project/chinese_ocr_densenet/train/images/medicine_dataset_v1/train/.*png')
# img_path = '/mnt/wuwenhui/git_ocr_project/chinese_ocr_densenet/train/images/medicine_dataset_v1/train/T1058_7.png'
# img_path = '/mnt/wuwenhui/git_ocr_project/keras_crnn/train/data/pytorch_densenet/competiton_final/train_f/T1058_7.png'
# result = Image.open(img_path)
plt.imshow(result)
print(item)
result.size

# %%
import keys_keras
characters_crnn = keys_keras.alphabet_union[:]
characters = keys.alphabet[:]

diff_set = (set(characters) | set(characters_crnn))-set(characters)

# %%
# ''.join(sorted(list(diff_set)))

# %%
alphabet_union = u""" ，的。一是0不在有、人“”了中国大为1:上2这个以年生和我时之也来到要会学对业出行公能他于5e3而发地可作就自们后成家日者分多下其用方本得子.高4过经6现说与前o理工所力t如将军部,事进9司场同机主都实天面市8ia新动开n关定还长此月7道美心法最文等当第好然体全比股通性重三外s但战;相从你r内无考因小资种合情去里化次入加间些度?员意没产正表很队报已名海点目着应解那看数东位题利起二民提及明教问）制期（元游女-并曰十果)么注两专样信王平己金务使电网代手知计至常(只展品更系科门特想西l水做被北由c》万老向《记政今据量保建物区管见安集或认程h总—少身先师球价空旅又求校强各非立受术基活反!世何职导任取式[]试才结费把收联直规持赛社四山统投南原该院交达接头打设每别示则调处义权台感斯证言五议d给决论她告广企格增让指研商客太息近城变技医件几书选周备m流士京传u放病华单话招路界药回再%服什改育口张需治德复准马习真语难始"际观完标共项容级即必类领AC未w型案线运历首风视色尔整质参较云具布组办气造争往形份防p它车深神称g况推越英易且营条消命团确S划精足儿局飞究功索走望却查武思兵识克故步影带乐白源史航志州限清光装节号转图根省许引势失候济显百击f器象效仅爱官包供低演连夫快续支验阳男觉花死字创素半预音户约率声请票…便构T存食y段远责M拉房随断极销林亚隐超获升B采I算益优愿找按维态满尽令汉委八终训值负境练母热适江住列举景置黄听除读众响友助�